pdf', '14 - pooja sahu.pdf', '14-02-2020-BUSHAN_RESUME - Dipak Gujrathi.pdf', '15 - pooja sahu(1).pdf', '15 - pooja sahu.pdf', '1543913748429_0_Basudev Mistri-2(1) - prabhawati Kumari.docx', '1550040009880_ANUPAMA RESUME - Prasanna.docx', '1557038904816_Shubham Khare Resume (1) - raksha khare.docx', '1560146151893Resume_Supraja PDF-converted(3) - vinay ks.docx', '1564396531520_1903034-converted - alapati anitha.pdf', '1564413030_cand_ui - Pooja Sundaramurthy.docx', '1564462100_cand_Mohits_Resume - Pooja Sundaramurthy.pdf', '1567597529876_Balaji resume - Ankita Mane.docx', '1567757818475_SYED NASEER UDDIN - Mallick Bhagyashree.docx', '1570635060_cand_Devi - HARISH R 19MBA016.pdf', '1576162210605Resume_jetti-converted - Tanzil blitzjobs.pdf', '1576587602_cand_NaveenResume-exp - Pooja Sundaramurthy.docx', '1576839392_cand_Vijay_Yadav_NET - Pooja Sundaramurthy.docx', '1578069768637_Aakash important - Tanzil blitzjobs.docx', '1578299542371Resume_Sumit - raksha khare.pdf', '1580020360918_0_shahbaz cv - Nandini Tiwari.pdf', '1580534111516_Sweta_Singh_HR_CV - sweta singh.pdf', '1581402989_cand_suresh_resume - Pooja Sundaramurthy.docx', '1581596555025_NewRR - supriya s.doc', '1582041058756Resume_MNVS_19-Feb-20_08.56.07 - vinay ks(1).pdf', '1582041058756Resume_MNVS_19-Feb-20_08.56.07 - vinay ks.pdf', '1582819374278_kkresum - Vishal kumar.docx', '1583298289524Resume_ROHIT - raksha khare.pdf', '1586374000884_Resume - ANKIT GARG - Vibhu Aggarwal.pdf', '1587717 ...

# %%
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
from os import *


def extract_text_from_pdf(pdf_path):
    with open(r'%s' % pdf_path, 'rb') as fh:
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            resource_manager = PDFResourceManager()
            fake_file_handle = StringIO()
            converter = TextConverter(
                                resource_manager,
                                fake_file_handle,
                                codec='utf-8',
                                laparams=LAParams()
                        )
            page_interpreter = PDFPageInterpreter(
                                resource_manager,
                                converter
                            )
            page_interpreter.process_page(page)
            text = fake_file_handle.getvalue()
            yield text
            converter.close()
            fake_file_handle.close()


dir_list = listdir(r'F:\CVS_Database')
# print(dir_list)
res_list = []
for i in dir_list:
    fake_file_handle = StringIO()
    text = fake_file_handle.getvalue()
    for page in extract_text_from_pdf(i):
        text += ' ' + page
    res_list.append(text)
print(res_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-184dca3ae624> in <module>
#      36     fake_file_handle = StringIO()
#      37     text = fake_file_handle.getvalue()
# ---> 38     for page in extract_text_from_pdf(i):
#      39         text += ' ' + page
#      40     res_list.append(text)
#
# <ipython-input-14-184dca3ae624> in extract_text_from_pdf(pdf_path)
#       9
#      10 def extract_text_from_pdf(pdf_path):
# ---> 11     with open(r'%s' % pdf_path, 'rb') as fh:
#      12         for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
#      13             resource_manager = PDFResourceManager()
#
# TypeError: an integer is required (got type str)
